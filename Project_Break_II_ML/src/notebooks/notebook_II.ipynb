# %% [markdown]
# # **2. Problema ML**
#
# Because we are assuming that this is a GDP growth estimation by country, this is a Supervised Learning Regression problem.

# %%
import pandas as pd
import numpy as np
from sklearn import linear_model
from sklearn import model_selection
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

plt.rc('font', size=14)
plt.rc('axes', labelsize=14, titlesize=14)
plt.rc('legend', fontsize=14)
plt.rc('xtick', labelsize=10)
plt.rc('ytick', labelsize=10)

# %%
df = pd.read_csv("src/data_sample/gdp_model_focused.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16900 entries, 0 to 16899
# Data columns (total 17 columns):
#  #   Column                                                      Non-Null Count  Dtype
# ---  ------                                                      --------------  -----
#  0   year                                                        16900 non-null  int64
#  1   country                                                     16900 non-null  object
#  2   GDP growth (annual %)                                       13575 non-null  float64
#  3   GDP per capita (constant 2015 US$)                          13695 non-null  float64
#  4   Gross fixed capital formation (% of GDP)                    9793 non-null   float64
#  5   Gross domestic savings (% of GDP)                           10497 non-null  float64
#  6   Inflation, GDP deflator (annual %)                          13470 non-null  float64
#  7   Exports of goods and services (% of GDP)                    10802 non-null  float64
#  8   Imports of goods and services (% of GDP)                    10819 non-null  float64
#  9   Foreign direct investment, net inflows (% of GDP)           11251 non-null  float64
#  10  Population growth (annual %)                                16348 non-null  float64
#  11  Industry (including construction), value added (% of GDP)   10588 non-null  float64
#  12  Agriculture, forestry, and fishing, value added (% of GDP)  10679 non-null  float64
#  13  Services, value added (% of GDP)                            10033 non-null  float64
#  14  School enrollment, secondary (% gross)                      9386 non-null   float64
#  15  Literacy rate, adult total (% of people ages 15 and above)  2671 non-null   float64
#  16  Access to electricity, rural (% of rural population)        7314 non-null   float64
# dtypes: float64(15), int64(1), object(1)
# memory usage: 2.2+ MB

# %%
df.columns
# Out:
# Index(['year', 'country', 'GDP growth (annual %)',
#        'GDP per capita (constant 2015 US$)',
#        'Gross fixed capital formation (% of GDP)',
#        'Gross domestic savings (% of GDP)',
#        'Inflation, GDP deflator (annual %)',
#        'Exports of goods and services (% of GDP)',
#        'Imports of goods and services (% of GDP)',
#        'Foreign direct investment, net inflows (% of GDP)',
#        'Population growth (annual %)',
#        'Industry (including construction), value added (% of GDP)',
#        'Agriculture, forestry, and fishing, value added (% of GDP)',
#        'Services, value added (% of GDP)',
#        'School enrollment, secondary (% gross)',
#        'Literacy rate, adult total (% of people ages 15 and above)',
#        'Access to electricity, rural (% of rural population)'],
#       dtype='object')

# %%
df["GDP growth (annual %)"].value_counts()
# Out:
# GDP growth (annual %)
#  0.000000     15
#  3.761612      2
#  0.619467      2
#  4.286275      2
#  11.647093     2
#               ..
# -0.236337      1
#  3.772402      1
#  6.054514      1
#  10.399009     1
#  5.336730      1
# Name: count, Length: 13434, dtype: int64

# %%
df.head()
# Out:
#    year country  GDP growth (annual %)  GDP per capita (constant 2015 US$)  \
# 0  1960     ABW                    NaN                                 NaN
# 1  1960     AFE                    NaN                         1172.316285
# 2  1960     AFG                    NaN                                 NaN
# 3  1960     AFW                    NaN                         1110.513849
# 4  1960     AGO                    NaN                                 NaN
#
#    Gross fixed capital formation (% of GDP)  \
# 0                                       NaN
# 1                                       NaN
# 2                                       NaN
# 3                                       NaN
# 4                                       NaN
#
#    Gross domestic savings (% of GDP)  Inflation, GDP deflator (annual %)  \
# 0                                NaN                                 NaN
# 1                                NaN                                 NaN
# 2                                NaN                                 NaN
# 3                                NaN                                 NaN
# 4                                NaN                                 NaN
#
#    Exports of goods and services (% of GDP)  \
# 0                                       NaN
# 1                                       NaN
# 2                                       NaN
# 3                                       NaN
# 4                                       NaN
#
#    Imports of goods and services (% of GDP)  \
# 0                                       NaN
# 1                                       NaN
# 2                                       NaN
# 3                                       NaN
# 4                                       NaN
#
#    Foreign direct investment, net inflows (% of GDP)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Population growth (annual %)  \
# 0                           NaN
# 1                           NaN
# 2                           NaN
# 3                           NaN
# 4                           NaN
#
#    Industry (including construction), value added (% of GDP)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Agriculture, forestry, and fishing, value added (% of GDP)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Services, value added (% of GDP)  School enrollment, secondary (% gross)  \
# 0                               NaN                                     NaN
# 1                               NaN                                     NaN
# 2                               NaN                                     NaN
# 3                               NaN                                     NaN
# 4                               NaN                                     NaN
#
#    Literacy rate, adult total (% of people ages 15 and above)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Access to electricity, rural (% of rural population)
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN

# %%
df.value_counts()
# Out:
# year  country  GDP growth (annual %)  GDP per capita (constant 2015 US$)  Gross fixed capital formation (% of GDP)  Gross domestic savings (% of GDP)  Inflation, GDP deflator (annual %)  Exports of goods and services (% of GDP)  Imports of goods and services (% of GDP)  Foreign direct investment, net inflows (% of GDP)  Population growth (annual %)  Industry (including construction), value added (% of GDP)  Agriculture, forestry, and fishing, value added (% of GDP)  Services, value added (% of GDP)  School enrollment, secondary (% gross)  Literacy rate, adult total (% of people ages 15 and above)  Access to electricity, rural (% of rural population)
# 1990  MUS      7.186737               3810.480833                         30.176859                                  24.034973                         10.583631                           64.093928                                 71.196573                                 1.526106                                           0.712313                      27.414859                                                  10.742782                                                   45.440416                         52.564220                               80.000000                                                   98.291560                                               1
# 2015  SLV      2.400000               3790.340891                         15.692177                                 -1.570980                          1.307618                            29.486173                                 47.074098                                 2.109978                                           0.335655                      25.288930                                                  5.529767                                                    60.013039                         70.698189                               88.000000                                                   89.400000                                               1
#       TLA      0.359823               8617.552912                         20.296910                                  17.771711                         2.896240                            20.962153                                 23.022586                                 3.479542                                           1.016423                      28.849180                                                  5.485419                                                    67.726813                         94.989380                               93.298058                                                   88.848114                                               1
#       THA      3.134047               5688.853354                         24.528489                                  31.534146                         0.722114                            67.636690                                 57.202972                                 2.224685                                           0.460976                      36.179177                                                  8.872724                                                    54.948099                         126.035988                              93.000000                                                   99.500000                                               1
#       TEC      1.487560               8001.112292                         23.426105                                  26.270482                         2.219573                            32.664348                                 30.502554                                 2.035130                                           0.510644                      29.290774                                                  5.636369                                                    54.210151                         98.867348                               98.996742                                                   98.722259                                               1
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     ..
# 2008  IBT      5.839190               3430.877433                         28.280249                                  33.048336                         9.390111                            31.388703                                 29.247665                                 3.647964                                           1.356603                      36.272480                                                  8.974751                                                    48.532821                         64.655243                               80.517548                                                   68.724395                                               1
#       IBD      5.908709               4155.013271                         28.680727                                  34.082197                         9.592327                            32.043582                                 29.195131                                 3.689655                                           1.026633                      37.175302                                                  7.842354                                                    48.701713                         74.964493                               85.887199                                                   82.888132                                               1
#       HPC      5.638236               789.550368                          22.439727                                  18.240708                         9.554749                            26.049770                                 35.591486                                 4.102058                                           2.821655                      24.502189                                                  24.491310                                                   39.460099                         32.475330                               53.969990                                                   11.235782                                               1
#       ESP      0.767166               27112.526300                        27.856624                                  23.746530                         2.452044                            25.547809                                 30.280323                                 4.528325                                           1.595330                      26.186949                                                  2.353672                                                    63.627170                         117.210587                              98.000000                                                   100.000000                                              1
# 2023  TSS      2.799269               1581.056829                         23.643703                                  4.097101                          4.731997                            25.558522                                 27.341461                                 2.107922                                           2.497036                      27.084985                                                  16.945693                                                   45.112431                         44.787041                               68.196243                                                   33.948123                                               1
# Name: count, Length: 1378, dtype: int64

# %% [markdown]
# # **3. Target**

# %%
target = "GDP growth (annual %)"

# %%
plt.figure(figsize=(10, 6))
sns.histplot(data=df, x="GDP growth (annual %)", bins=30)
plt.title('GDP Growth Distribution')
plt.axvline(df["GDP growth (annual %)"].mean(), color='red', linestyle='--', label=f'Mean: {df["GDP growth (annual %)"].mean():.2f}%')
plt.legend()
plt.show()

# %%
plt.figure(figsize=(8, 6))
sns.violinplot(data=df, y="GDP growth (annual %)")
plt.title('GDP Growth - Violin Plot')
plt.show()

# %%
sns.histplot(data=df, x="GDP growth (annual %)", bins=30)
plt.show()

# Or if you want to bin the continuous values into categories first:
df['GDP_growth_category'] = pd.cut(df["GDP growth (annual %)"], 
                                  bins=[-float('inf'), -2, 0, 2, 4, float('inf')], 
                                  labels=['Recession', 'Low', 'Moderate', 'High', 'Very High'])
sns.countplot(data=df, x='GDP_growth_category')
plt.show()

# %%
print("GDP Growth - Descriptive Statistics:")
print(df["GDP growth (annual %)"].describe())
print(f"\nSkewness: {df['GDP growth (annual %)'].skew():.3f}")
print(f"Kurtosis: {df['GDP growth (annual %)'].kurtosis():.3f}")
# Out:
# GDP Growth - Descriptive Statistics:
# count    13575.000000
# mean         3.669586
# std          6.230779
# min        -64.047107
# 25%          1.373394
# 50%          3.807604
# 75%          6.152008
# max        149.972963
# Name: GDP growth (annual %), dtype: float64
#
# Skewness: 1.835
# Kurtosis: 49.315

# %%
# Set style for better looking plots
plt.style.use('default')
sns.set_palette("husl")

# Create subplots for multiple visualizations
fig, axes = plt.subplots(2, 2, figsize=(15, 12))
fig.suptitle('GDP Growth (Annual %) - Target Variable Analysis', fontsize=16, fontweight='bold')

# 1. Distribution plot (histogram + KDE)
sns.histplot(data=df, x="GDP growth (annual %)", kde=True, ax=axes[0,0])
axes[0,0].set_title('Distribution of GDP Growth')
axes[0,0].axvline(df["GDP growth (annual %)"].mean(), color='red', linestyle='--', label=f'Mean: {df["GDP growth (annual %)"].mean():.2f}%')
axes[0,0].axvline(df["GDP growth (annual %)"].median(), color='orange', linestyle='--', label=f'Median: {df["GDP growth (annual %)"].median():.2f}%')
axes[0,0].legend()

# 2. Box plot to see outliers
sns.boxplot(data=df, y="GDP growth (annual %)", ax=axes[0,1])
axes[0,1].set_title('Box Plot - Outlier Detection')

# 3. Time series plot (if you have a time/date column)
# Replace 'Year' with your actual time column name
if 'Year' in df.columns:
    sns.lineplot(data=df, x="Year", y="GDP growth (annual %)", ax=axes[1,0])
    axes[1,0].set_title('GDP Growth Over Time')
    axes[1,0].tick_params(axis='x', rotation=45)
else:
    # If no time column, show a simple line plot by index
    axes[1,0].plot(df.index, df["GDP growth (annual %)"])
    axes[1,0].set_title('GDP Growth by Data Point')
    axes[1,0].set_xlabel('Index')

# 4. Q-Q plot to check normality
from scipy import stats
stats.probplot(df["GDP growth (annual %)"].dropna(), dist="norm", plot=axes[1,1])
axes[1,1].set_title('Q-Q Plot (Normality Check)')

plt.tight_layout()
plt.show()

# %%
print(f"\nMissing values: {df['GDP growth (annual %)'].isnull().sum()}")
print(f"Percentage missing: {(df['GDP growth (annual %)'].isnull().sum() / len(df))* 100:.2f}%")
# Out:
# Missing values: 3325
# Percentage missing: 19.67%

# %%
fig, axes = plt.subplots(1, 4, figsize=(20, 5), sharey=True)


# Original target
sns.histplot(target, kde=False, ax=axes[0])
axes[0].set_title("Original target")

# Logaritmic
sns.histplot(np.log(target),kde=False, ax=axes[1])
axes[1].set_title("Log")

# Box-cox
sns.histplot(stats.boxcox(target)[0],kde=False, ax=axes[2])
axes[2].set_title("Box-Cox");

# Power 2
sns.histplot(np.power(target, 2),kde=False, ax=axes[3])
axes[3].set_title("Power 2");
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[36], line 9
#       6 axes[0].set_title("Original target")
#       8 # Logaritmic
# ----> 9 sns.histplot(np.log(target),kde=False, ax=axes[1])
#      10 axes[1].set_title("Log")
#      12 # Box-cox
#
# TypeError: ufunc 'log' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''

# %% [markdown]
# # **4. Train and Test**

# %%
df["target"] = df["GDP growth (annual %)"]

# %%
X_train, X_test, y_train, y_test = train_test_split(df.drop("target", axis=1),
                                                    df['target'],
                                                    test_size=0.2,
                                                    random_state=42)
